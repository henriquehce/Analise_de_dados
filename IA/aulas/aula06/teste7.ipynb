# %%
import json
from contato_com_llm import recebe_linha_e_retorna_json

# Etapa 1
lista_de_resenhas = []

with open("Resenhas_App_ChatGPT.txt", "r", encoding="utf-8") as arquivo:
    for linha in arquivo:
        lista_de_resenhas.append(linha.strip())

# Etapa 2 e 3
lista_de_resenhas_json = []

def classificar_resenha_local(resenha):
    texto = resenha.strip().lower()
    palavras_positivas = ["excelente", "bom", "rápida", "perfeitas", "superou"]
    palavras_negativas = ["ruim", "lixo", "péssimo", "pessimo", "não gostei", "nao gostei"]

    if any(palavra in texto for palavra in palavras_negativas):
        avaliacao = "Negativa"
    elif any(palavra in texto for palavra in palavras_positivas):
        avaliacao = "Positiva"
    else:
        avaliacao = "Neutra"

    return {"resenha": resenha.strip(), "avaliacao": avaliacao}

for resenha in lista_de_resenhas:
    try:
        resenha_json = recebe_linha_e_retorna_json(resenha)
        resenha_dict = json.loads(resenha_json)
    except Exception:
        resenha_dict = classificar_resenha_local(resenha)

    if "avaliacao" not in resenha_dict:
        resenha_dict["avaliacao"] = "Neutra"

    lista_de_resenhas_json.append(resenha_dict)

# Etapa 4
def contador_e_juntador(lista_de_dicionarios):
    contador_positivas = 0
    contador_negativas = 0
    contador_neutras = 0
    lista_de_dicionarios_str = []

    for dicionario in lista_de_dicionarios:
        if dicionario['avaliacao'] == 'Positiva':
            contador_positivas += 1
        elif dicionario['avaliacao'] == 'Negativa':
            contador_negativas += 1
        else:
            contador_neutras += 1
        
        lista_de_dicionarios_str.append(str(dicionario))

    textos_unidos = "#####".join(lista_de_dicionarios_str)

    return contador_positivas, contador_negativas, contador_neutras, textos_unidos

pos, neg, neut, textos = contador_e_juntador(lista_de_resenhas_json)
print(f"Positivas: {pos}\n")
print(f"Negativas: {neg}\n")
print(f"Neutras: {neut}\n")
print(textos)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\henri\anaconda3\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\henri\anaconda3\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\henri\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
# ...
